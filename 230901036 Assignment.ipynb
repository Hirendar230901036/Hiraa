# %%
import pandas as pd
a=[77,86,98,99,57,87,90,43,33,23,56,76,43,33,44,52,11,55,67,84]
b=['hari','ramesh','dinesh','suresh','harish','raj','raman','krish','naman','dhir','hardik','pandya','sulek','sam','chris','sai','subash','ram','nandha','ravi']
c=[]
d=[]
e=0
f=0
for i in a:
    if i>=90:
        d.append("Pass")
        c.append("A")
        f+=1
    elif i>=80:
        d.append("Pass")
        c.append("B")
        f+=1
    elif i>=70:
        d.append("Pass")
        c.append("C")
        f+=1
    elif i>=60:
       d.append("Pass") 
       c.append("D")
       f+=1
    elif i>=50:
        d.append("Pass")
        c.append("E")
        f+=1
    else:
        d.append("Fail")
        c.append("F")
        e+=1
df=pd.DataFrame({"Student":b,"marks":a,"grade":c,'result':d})
print("\nOverall performance\n",df)
print("\nAverage marks:",df['marks'].mean())
print("\nHighest marks:",df['marks'].max())
print("\nLowest marks:",df['marks'].min())
print("\nNumber of students passed:",f)
print("\nNumber of students failed:",e)
# Out:
# Overall performance
#     Student  marks grade result
# 0     hari     77     C   Pass
# 1   ramesh     86     B   Pass
# 2   dinesh     98     A   Pass
# 3   suresh     99     A   Pass
# 4   harish     57     E   Pass
# 5      raj     87     B   Pass
# 6    raman     90     A   Pass
# 7    krish     43     F   Fail
# 8    naman     33     F   Fail
# 9     dhir     23     F   Fail
# 10  hardik     56     E   Pass
# 11  pandya     76     C   Pass
# 12   sulek     43     F   Fail
# 13     sam     33     F   Fail
# 14   chris     44     F   Fail
# 15     sai     52     E   Pass
# 16  subash     11     F   Fail
# 17     ram     55     E   Pass
# 18  nandha     67     D   Pass
# 19    ravi     84     B   Pass
#
# Average marks: 60.7
#
# Highest marks: 99
#
# Lowest marks: 11
#
# Number of students passed: 13
#
# Number of students failed: 7

# %%
import numpy as np
A=np.array(([2,3],[4,3]))
b=np.array([2,3])
print("\nGiven equation: Ax=b")
print("\nA=",A)
print("\nb=",b)
x=np.linalg.solve(a,b)
print("\nThe solution vector x=",x)
# Out:
# Given equation: Ax=b
#
# A= [[2 3]
#  [4 3]]
#
# b= [2 3]
#
# The solution vector x= [0.5        0.33333333]

# %%
print(" DAILY STEP COUNT          \n     ")
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
a=np.array([5443,5436,8765,4435,7645,1333,1211,3415,4524,3133,2113,5456,1222,1221,2345,6534,5443,6742,7345,
            1235,2523,5454,3223,2323,2331,5421,3345,5215,1555,4222])  
b=[f"{i}"for i in range(1,31)]
df=pd.DataFrame({'Days':b,'steps':a})
print(df)
print("\nAverage steps per day:",a.mean())
print("\nTotal steps:",a.sum())
print("\nMaximum step counts recorded:",a.max())
print("\nMinimum step counts recorded:",a.min())
c=[]
for i in range(len(a)):
    if a[i]>7000:
       c.append(i+1) 
print("\nDays with high activity(steps above 7000):",c)
print("\n")
plt.plot(b,a)
plt.title('Daily step count')
plt.xlabel('Days')
plt.ylabel('Steps')
print("\nVisualization:\n")
print(plt.show())
# Out:
#  DAILY STEP COUNT
#
#    Days  steps
# 0     1   5443
# 1     2   5436
# 2     3   8765
# 3     4   4435
# 4     5   7645
# 5     6   1333
# 6     7   1211
# 7     8   3415
# 8     9   4524
# 9    10   3133
# 10   11   2113
# 11   12   5456
# 12   13   1222
# 13   14   1221
# 14   15   2345
# 15   16   6534
# 16   17   5443
# 17   18   6742
# 18   19   7345
# 19   20   1235
# 20   21   2523
# 21   22   5454
# 22   23   3223
# 23   24   2323
# 24   25   2331
# 25   26   5421
# 26   27   3345
# 27   28   5215
# 28   29   1555
# 29   30   4222
#
# Average steps per day: 4020.266666666667
#
# Total steps: 120608
#
# Maximum step counts recorded: 8765
#
# Minimum step counts recorded: 1211
#
# Days with high activity(steps above 7000): [3, 5, 19]
#
#
#
# Visualization:
# None

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
a=[f"{i}"for i in range(1,31)]
b=np.random.randint(30,100,size=(30,3))
math=b[:,1]
science=b[:,2]
english=b[:,0]
total=[]
for i in range(len(a)):
    total.append(math[i]+science[i]+english[i])
total=np.array(total)
df=pd.DataFrame({'Roll no':a,' English':english,' Mathematics':math,' Science':science,'  Total':total})
print("\nClass Overall Performance:\n",df)
print("\nOverall Average marks:",(math.mean()+science.mean()+english.mean()).mean())
print("\nHighest marks:",total.max())
print("\nLowest marks:",total.min())
c=[]
max=0
s=0
for i in range(len(total)):
    if total[i]>220:
        c.append(i+1)
    if total[i]>max:
        max=total[i] 
        s=i
c=np.array(c)
print("\nTop performing students based on total marks obtained: roll numbers:",c)
print("\nTopper of the class:",'\nroll no:',s,'\nmarks:',max)
print("\nVisualization of Class performance based on subjects:")
plt.bar(a,math)
plt.xlabel('roll no')
plt.ylabel('marks')
plt.title('Mathematics')
plt.show()
plt.bar(a,science)
plt.xlabel('roll no')
plt.ylabel('marks')
plt.title('Science')  
plt.show()
plt.bar(a,english)
plt.xlabel('roll no')
plt.ylabel('marks')
plt.title('English')
plt.show()
# Out:
# Class Overall Performance:
#     Roll no   English   Mathematics   Science    Total
# 0        1        95            93        93      281
# 1        2        33            58        98      189
# 2        3        50            95        51      196
# 3        4        42            93        97      232
# 4        5        71            66        81      218
# 5        6        90            76        90      256
# 6        7        68            36        92      196
# 7        8        50            33        34      117
# 8        9        88            86        95      269
# 9       10        62            30        85      177
# 10      11        47            60        64      171
# 11      12        96            96        67      259
# 12      13        75            64        79      218
# 13      14        86            66        34      186
# 14      15        89            82        60      231
# 15      16        56            79        75      210
# ...

# %%
#QUESTION-3A

import cmath
import pandas as pd
def imp(c,v,f):
  w=2*cmath.pi*f
  if c=='R':
    return complex(v,0)
  elif c=='L':
    return complex(0,w*v)
  elif c=='C':
    return complex(0,-1/(w*v))
  else:
    return 'Invalid component'
def tot(df,config):
  if config=='Series':
    return df['Impedance'].sum()
  else:
    return 1 / sum(1 / z for z in df['Impedance'])
f=float(input("Enter Frequency:"))
config=input("Enter the configuration(Series/Parallel):")
n=int(input('No of components:'))
d=[]
for i in range(n):
  c=input("Enter the component(R/L/C):").upper()
  v=float(input("Enter the value:"))
  z=imp(c,v,f)
  d.append({'Component':f'{c}{i+1}','Type':c,'Value': v, 'Impedance': z})
df=pd.DataFrame(d)
pd.set_option("display.precision",2)
print(df)
t=tot(df,config)
print(f'Total Impedance:{t:.2f}')
# Out:
# Enter Frequency: 50
# Enter the configuration(Series/Parallel): Series
# No of components: 3
# Enter the component(R/L/C): R
# Enter the value: 5
# Enter the component(R/L/C): R
# Enter the value: 3
# Enter the component(R/L/C): L
# Enter the value: 4
#   Component Type  Value      Impedance
# 0        R1    R    5.0  5.00+   0.00j
# 1        R2    R    3.0  3.00+   0.00j
# 2        L3    L    4.0  0.00+1256.64j
# Total Impedance:8.00+1256.64j

# %%
import numpy as np
stock1=np.array((([103,144,334],[202,321,123],[342,221,112],[123,142,123],[98,80,90])))
print("\nStock1:\n",stock1)
stock2=np.array((([98,132,331],[200,319,120],[340,210,110],[121,141,122],[97,79,88])))
print("\nStock 2:\n",stock2)
print("\nCombined price value of two stocks:\n",stock1+stock2)
print("\nDaily spread between two stocks:\n",stock1-stock2)
# Out:
# Stock1:
#  [[103 144 334]
#  [202 321 123]
#  [342 221 112]
#  [123 142 123]
#  [ 98  80  90]]
#
# Stock 2:
#  [[ 98 132 331]
#  [200 319 120]
#  [340 210 110]
#  [121 141 122]
#  [ 97  79  88]]
#
# Combined price value of two stocks:
#  [[201 276 665]
#  [402 640 243]
#  [682 431 222]
#  [244 283 245]
#  [195 159 178]]
#
# Daily spread between two stocks:
#  [[ 5 12  3]
#  [ 2  2  3]
#  [ 2 11  2]
#  [ 2  1  1]
#  [ 1  1  2]]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
sampling_rate = 20  # Hz
duration = 1  # in seconds
t = np.linspace(0, duration, int(sampling_rate * duration), endpoint=False)
def generate_wave(freq, amp, noise_level):
    signal = amp * np.sin(2 * np.pi * freq * t)
    noise = np.random.normal(0, noise_level, t.shape)
    return signal + noise
data={
    'Patient_ID':[f"{i}" for i in range(1,21)],
    'Time(s)':t,
    'Delta': generate_wave(2, 10, 10),
    'Theta': generate_wave(6, 6, 8),
    'Alpha': generate_wave(10, 4, 5),
    'Beta':  generate_wave(20, 5, 3)
}
df = pd.DataFrame(data)
df.to_csv(r"C:\Users\Hiren\Downloads\EEG-11 - Sheet1.csv",index=False)
print(df)
print("\nStatistics (Mean, Variance, Max):")
print('Mean:\n',df[['Delta', 'Theta', 'Alpha', 'Beta']].mean())
print('Variance:\n',df[['Delta', 'Theta', 'Alpha', 'Beta']].var())
print('Max:\n',df[['Delta', 'Theta', 'Alpha', 'Beta']].max())
plt.bar(df['Patient_ID'],df['Delta'])
plt.xlabel('Patient_ID')
plt.ylabel('Delta')
plt.show()
plt.bar(df['Patient_ID'],df['Theta'])
plt.xlabel('Patient_ID')
plt.ylabel('Theta')
plt.show()
plt.bar(df['Patient_ID'],df['Alpha'])
plt.xlabel('Patient_ID')
plt.ylabel('Alpha')
plt.show()
plt.bar(df['Patient_ID'],df['Beta'])
plt.xlabel('Patient_ID')
plt.ylabel('Beta')
plt.show()
# Out:
#    Patient_ID  Time(s)  Delta  Theta  Alpha   Beta
# 0           1     0.00  -9.82  -2.43  -4.67   1.15
# 1           2     0.05  10.25  -8.78  -8.06  -2.83
# 2           3     0.10  -9.39 -10.80  -2.93  -2.32
# 3           4     0.15  -7.04 -14.12  -4.82  -3.88
# 4           5     0.20  14.81  -8.46   4.78  -4.24
# 5           6     0.25  -4.21  -0.99  -0.46 -10.24
# 6           7     0.30  -6.55   2.88   1.57  -0.53
# 7           8     0.35  -9.43  -1.65   0.54  -1.76
# 8           9     0.40  -3.33   0.88   4.47   1.27
# 9          10     0.45  -1.58 -16.74  -7.58   2.56
# 10         11     0.50  10.21  -4.93  -1.11  -5.44
# 11         12     0.55  18.66  11.96   2.20   0.03
# 12         13     0.60   4.52  -9.29   6.91   0.37
# 13         14     0.65  20.41 -10.89  -3.71   4.12
# 14         15     0.70  14.94  -3.51   0.40  -3.00
# 15         16     0.75  10.37   4.17  -0.40   3.03
# 16         17     0.80   1.77   9.25   0.01  -1.91
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
data={'Product':['Laptop','Smartphone','Tablet','Monitor','Keyboard'],'Price':[1200,800,300,150,50],
      'Quantity':[10,20,15,25,50]}
df=pd.DataFrame(data)
d1={'Company':['Dell','Samsung','Apple','Microsoft','Logitech']}
df1=pd.DataFrame(d1)
print("\nOriginal dataframe:\n",df)
print("\nNew Column added:\n",df.join(df1))
print("\nTotal quantity of the products:",df['Quantity'].sum())
print("\nMaximum price:",df['Price'].max())
print("\nMinimum price:",df['Price'].min())
plt.bar(df['Product'],df['Quantity'])
plt.xlabel('Product')
plt.ylabel('Price')
plt.show()
plt.pie(df['Price'],labels=df['Product'])
plt.show()
# Out:
# Original dataframe:
#        Product  Price  Quantity
# 0      Laptop   1200        10
# 1  Smartphone    800        20
# 2      Tablet    300        15
# 3     Monitor    150        25
# 4    Keyboard     50        50
#
# New Column added:
#        Product  Price  Quantity    Company
# 0      Laptop   1200        10       Dell
# 1  Smartphone    800        20    Samsung
# 2      Tablet    300        15      Apple
# 3     Monitor    150        25  Microsoft
# 4    Keyboard     50        50   Logitech
#
# Total quantity of the products: 120
#
# Maximum price: 1200
#
# Minimum price: 50

# %%
import pandas as pd
sheet_id = '1jVHGkKb1P_iwZAbbQ98aUUWVIJAfPUeksIwifQeY1ao'
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv"
df = pd.read_csv(url)
print(df)
print("\nFirst 5 rows of dataframe:\n",df.head())
a=df.ffill()
print("\nReplacing NaN values:\n",a)
plt.xlabel('Month')
plt.ylabel('Sales(%)')
plt.bar(a['Month'],a['Sales(%)'])
plt.show()
# Out:
#         Month  Sales(%)
# 0     January      90.0
# 1     Febrary      70.0
# 2       March      68.0
# 3       April      79.0
# 4         May       NaN
# 5        June      88.0
# 6        July      77.0
# 7      August      66.0
# 8   September      88.0
# 9     October      76.0
# 10   November      77.0
# 11   December      94.0
#
# First 5 rows of dataframe:
#       Month  Sales(%)
# 0  January      90.0
# 1  Febrary      70.0
# 2    March      68.0
# 3    April      79.0
# 4      May       NaN
#
# Replacing NaN values:
#          Month  Sales(%)
# 0     January      90.0
# 1     Febrary      70.0
# 2       March      68.0
# 3       April      79.0
# 4         May      79.0
# 5        June      88.0
# 6        July      77.0
# 7      August      66.0
# 8   September      88.0
# 9     October      76.0
# 10   November      77.0
# 11   December      94.0

# %%
import pandas as pd
sheet_id ='1y1sLJE-CYg-MhhctnLj9rC8cKw7f3ZUh5-sVSoTebfY'
url=f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv"
df=pd.read_csv(url)
print(df)
print("Column names and data types:")
print(df.dtypes)
avg=df['Age'].mean()
print("\nAverage Age of the Patients:",avg)
y=df['Diagnosis'].value_counts()
plt.bar(y.index,y.values)
plt.xlabel('Diagnosis')
plt.ylabel('Frequency')
plt.show()
# Out:
#     PatientID  Age  Gender     Diagnosis             Medical History
# 0           1   34  Female       Healthy                     Obesity
# 1           2   30  Female  Hypertension  Family history of diabetes
# 2           3   43    Male        Asthma                     Obesity
# 3           4   64  Female        Asthma                      Smoker
# 4           5   73    Male        Cancer                         NaN
# ..        ...  ...     ...           ...                         ...
# 95         96   55  Female      Diabetes                         NaN
# 96         97   39    Male  Hypertension                      Smoker
# 97         98   31  Female        Cancer                         NaN
# 98         99   50    Male        Asthma                         NaN
# 99        100   76  Female        Cancer                Chronic pain
#
# [100 rows x 5 columns]
# Column names and data types:
# PatientID           int64
# Age                 int64
# Gender             object
# ...
